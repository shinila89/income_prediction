# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
income=pd.read_csv('incomeData.csv')
income
# Out:
#        nan          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# fields include
#
# age:The age of the person
#
# workclass:The working class of the person
#
# education:The educational qualification of the person
#
# education-num:The quantitative values with reference to education
#
# marital-status: The marital status of the person
#
# occupation:  The occupation of a person
#
# relationship:The people present in the family
#
# race:The person’s origins
#
# sex:The person's gender
#
# capital-gain:The monitory gains by the person
#
# capital-loss:The monitory loss by the person
#
# hours-per-week:The number of working hours per week by the person
#
# native-country: The country to which the person belongs

# %%
income.isna().sum()
# Out:
# nan               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
income.shape
# Out:
# (32561, 15)

# %%
income.describe().T
# Out:
#                   count           mean            std      min       25%  \
# nan             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# capital-gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital-loss    32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# nan                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %%
income.columns
# Out:
# Index(['nan', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Income'],
#       dtype='object')

# %%
income.rename(columns={'nan':'age'},inplace=True)
income
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Observation
#
# There are in total 32561 samples in the income data set
#
# There are both categorical and numerical attributes in the dataset

# %%
cols=income.columns

# %%
for col in cols :
    print("{} : {}".format(cols,income[col].unique()))
#checking unique values in each variables
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Income'],
#       dtype='object') : [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Income'],
#       dtype='object') : [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
# ...

# %%
income['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
income['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
income['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
income['workclass'].replace(' ?',np.nan,inplace=True)

# %%
income['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', nan, ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
income['workclass'].isnull().sum()
# Out:
# 1836

# %%
income['occupation'].replace(' ?',np.nan,inplace=True)

# %%
income['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', nan, ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
income['occupation'].isnull().sum()
# Out:
# 1843

# %%
income['native-country'].replace(' ?',np.nan,inplace=True)

# %%
income['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', nan, ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
income['native-country'].isnull().sum()
# Out:
# 583

# %%
income.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# Income               0
# dtype: int64

# %% [markdown]
# fill the replace values

# %%
income['workclass'].fillna(method='ffill',inplace=True)
income['occupation'].fillna(method='ffill',inplace=True)
income['native-country'].fillna(method='ffill',inplace=True)

# %%
income.isna().sum()
# Out:
# nan               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
# checking duplicate values

# %%
income.duplicated().sum()
# Out:
# 24

# %%
income.drop_duplicates(inplace=True)

# %%
income.duplicated().sum()
# Out:
# 0

# %%
income.shape
# Out:
# (32537, 15)

# %%
income.to_csv("income_data_clean.csv")

# %%
income.describe(include='all').T
# Out:
#                   count unique                  top   freq           mean  \
# age             32537.0    NaN                  NaN    NaN      38.585549
# workclass         32537      8              Private  24071            NaN
# fnlwgt          32537.0    NaN                  NaN    NaN  189780.848511
# education         32537     16              HS-grad  10494            NaN
# education-num   32537.0    NaN                  NaN    NaN      10.081815
# marital-status    32537      7   Married-civ-spouse  14970            NaN
# occupation        32537     14       Prof-specialty   4382            NaN
# relationship      32537      6              Husband  13187            NaN
# race              32537      5                White  27795            NaN
# sex               32537      2                 Male  21775            NaN
# capital-gain    32537.0    NaN                  NaN    NaN    1078.443741
# capital-loss    32537.0    NaN                  NaN    NaN      87.368227
# ...

# %%
income.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076447       0.036224      0.077676      0.057745
# fnlwgt         -0.076447  1.000000      -0.043388      0.000429     -0.010260
# education-num   0.036224 -0.043388       1.000000      0.122664      0.079892
# capital-gain    0.077676  0.000429       0.122664      1.000000     -0.031639
# capital-loss    0.057745 -0.010260       0.079892     -0.031639      1.000000
# hours-per-week  0.068515 -0.018898       0.148422      0.078408      0.054229
#
#                 hours-per-week
# age                   0.068515
# fnlwgt               -0.018898
# education-num         0.148422
# capital-gain          0.078408
# capital-loss          0.054229
# hours-per-week        1.000000

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
def dist_box(data):
 # function plots a combined graph for univariate analysis of continous variable 
 #to check spread, central tendency , dispersion and outliers  
    Name=data.name.upper()
    fig,(ax_box,ax_dis)  =plt.subplots(nrows=2,sharex=True,gridspec_kw = {"height_ratios": (.25, .75)},figsize=(8, 5))
    mean=data.mean()
    median=data.median()
    mode=data.mode().tolist()[0]
    sns.set_theme(style="white")
    fig.suptitle("SPREAD OF DATA FOR "+ Name  , fontsize=18, fontweight='bold')
    sns.boxplot(x=data,showmeans=True, orient='h',color="teal",ax=ax_box)
    ax_box.set(xlabel='')
    # just trying to make visualisation better. This will set background to white
    sns.despine(top=True,right=True,left=True) # to remove side line from graph
    sns.distplot(data,kde=False,color='purple',ax=ax_dis)
    ax_dis.axvline(mean, color='r', linestyle='--',linewidth=2)
    ax_dis.axvline(median, color='g', linestyle='-',linewidth=2)
    ax_dis.axvline(mode, color='y', linestyle='-',linewidth=2)
    plt.legend({'Mean':mean,'Median':median,'Mode':mode})
#select all quantitative columns for checking the spread
list_col=  income.select_dtypes(include='number').columns.to_list()
for i in range(len(list_col)):
    dist_box(income[list_col[i]])

# %%
plt.figure(figsize=(14,20))

sns.set_theme(style="white") 
cols=["workclass","education","marital-status","occupation","relationship","race","sex","native-country","Income"]
for i, variable in enumerate(cols):
                     plt.subplot(9,2,i+1)
                     order = income[variable].value_counts(ascending=False).index   
             #sns.set_palette(list_palette[i]) # to set the palette
                     sns.set_palette('Set2')
                     ax=sns.countplot(x=income[variable], data=income )
                     sns.despine(top=True,right=True,left=True) # to remove side line from graph
                     for p in ax.patches:
                           percentage = '{:.1f}%'.format(100 * p.get_height()/len(income[variable]))
                           x = p.get_x() + p.get_width() / 2 - 0.05
                           y = p.get_y() + p.get_height()
                           plt.annotate(percentage, (x, y),ha='center')
                           
                     plt.tight_layout()
                     plt.title(cols[i].upper())

# %% [markdown]
# # Bivariate & Multivariate Analysis

# %%
sns.set_palette(sns.color_palette("Set2", 8))
plt.figure(figsize=(15,10))
sns.heatmap(income.corr(),annot=True)
plt.show()

# %%
sns.set_palette(sns.color_palette("Set1", 8))
sns.pairplot(income, hue="Income",corner=True)
plt.show()

# %%
income_high=income[income["Income"]==" >50K"]
income_high.shape
# Out:
# (7841, 15)

# %%
#plt.figure(figsize= [12,12])

sns.countplot(x="education", data=income_high)
sns.despine(top=True,right=True,left=True) # to remove side line from graph
plt.xticks(rotation=90)
plt.show()

# %%
income_low=income[income["Income"]==" <=50K"]
income_low.shape
# Out:
# (24720, 15)

# %%
#plt.figure(figsize= [12,12])

sns.countplot(x="workclass", data=income_high)
sns.despine(top=True,right=True,left=True) # to remove side line from graph
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="education", data=income_high,  hue="sex")
sns.despine(top=True,right=True,left=True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="education",data=income,hue="Income")
plt.xticks(rotation=90)
sns.despine(top=True,right=True,left=True)
plt.show()

# %%
sns.countplot(x="occupation",data=income,hue="Income")
plt.xticks(rotation=90)
sns.despine(top=True,right=True,left=True)
plt.show()

# %%
#plt.figure(figsize= [12,12])

sns.countplot(x="workclass", data=income_high)
sns.despine(top=True,right=True,left=True) # to remove side line from graph
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="education", data=income_high,  hue="sex")
sns.despine(top=True,right=True,left=True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="education",data=income,hue="Income")
plt.xticks(rotation=90)
sns.despine(top=True,right=True,left=True)
plt.show()

# %%
sns.countplot(x="occupation",data=income,hue="Income")
plt.xticks(rotation=90)
sns.despine(top=True,right=True,left=True)
plt.show()

# %%
income_high["education"].value_counts()
# Out:
#  Bachelors       2221
#  HS-grad         1675
#  Some-college    1387
#  Masters          959
#  Prof-school      423
#  Assoc-voc        361
#  Doctorate        306
#  Assoc-acdm       265
#  10th              62
#  11th              60
#  7th-8th           40
#  12th              33
#  9th               27
#  5th-6th           16
#  1st-4th            6
# Name: education, dtype: int64

# %%
income_high["occupation"].value_counts()
# Out:
#  Exec-managerial      1968
#  Prof-specialty       1859
#  Sales                 983
#  Craft-repair          929
#  Adm-clerical          507
#  Transport-moving      320
#  Tech-support          283
#  Machine-op-inspct     250
#  Protective-serv       211
#  ?                     191
#  Other-service         137
#  Farming-fishing       115
#  Handlers-cleaners      86
#  Armed-Forces            1
#  Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
income_high["native-country"].value_counts()
# Out:
#  United-States         7171
#  ?                      146
#  Philippines             61
#  Germany                 44
#  India                   40
#  Canada                  39
#  Mexico                  33
#  England                 30
#  Italy                   25
#  Cuba                    25
#  Japan                   24
#  Taiwan                  20
#  China                   20
#  Iran                    18
#  South                   16
#  Puerto-Rico             12
#  Poland                  12
#  France                  12
#  Jamaica                 10
#  El-Salvador              9
#  Greece                   8
#  Cambodia                 7
#  Hong                     6
#  Yugoslavia               6
#  Ireland                  5
#  Vietnam                  5
#  Portugal                 4
#  Haiti                    4
#  Ecuador                  4
#  Thailand                 3
#  Hungary                  3
#  Guatemala                3
#  Scotland                 3
# ...

# %%
income_high["race"].value_counts()
# Out:
#  White                 7117
#  Black                  387
#  Asian-Pac-Islander     276
#  Amer-Indian-Eskimo      36
#  Other                   25
# Name: race, dtype: int64

# %%
income_high["sex"].value_counts()
# Out:
#  Male      6662
#  Female    1179
# Name: sex, dtype: int64

# %%
sns.countplot(x="race",hue="Income",data=income)
plt.title("Income distribution by race")
plt.xlabel("race")
plt.ylabel("count")
plt.xticks(rotation=90)
plt.legend(title="Income",loc="upper right")
plt.show()

# %% [raw]
# White people have more income than others

# %%
sns.countplot(x="workclass",hue="Income",data=income)
plt.title("Income distribution by workclass")
plt.xlabel("workclass")
plt.ylabel("count")
plt.xticks(rotation=90)
plt.legend(title="Income",loc="upper right")
plt.show()

# %%
more people work in private sector

# %%
sns.countplot(x="education",hue="Income",data=income)
plt.title("Income distribution by education")
plt.xlabel("education")
plt.ylabel("count")
plt.xticks(rotation=90)
plt.legend(title="Income",loc="upper right")
plt.show()

# %%
sns.countplot(x='workclass',data=income_low)
plt.xticks(rotation=45)
plt.show()

# %%
income_high['sex'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='sex'>

# %%
income_low['sex'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='sex'>

# %%
sns.catplot(data=income,x='Income',y='age',kind='box')

# %% [raw]
# The average age of a person who have income greater than  50k is approximately 45 years of age and average age of a person who earn income lessthan 50k is 33 or 34 years of age

# %%
sns.catplot(data=income,x='Income',y='capital-gain',kind='bar',hue='sex')

# %% [raw]
# pearsons who have Income above 50k have more capital gain.

# %%
sns.countplot(x='Income',data=income,hue='marital-status')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.5,1), loc='upper right')
plt.show()

# %% [raw]
# More than 10000 never married people earns less than 50k.More than 60000 married person earns above 50k.

# %%
sns.countplot(x='Income',data=income,hue='education',palette='Paired')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.5,1), loc='upper right')
plt.show()

# %% [raw]
# more than 8000 HS-grade educated people earn less than 50k income . Nearly 3000 bachelors earn morethan 50k income

# %% [markdown]
# ENCODING DATA

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import preprocessing

# %%
label_enc=preprocessing.LabelEncoder()

# %%
p=income.copy()

# %%
for col in p:
    p[col]=label_enc.fit_transform(p[col].values)

# %%
p
# Out:
#        nan  workclass  fnlwgt  education  education-num  marital-status  \
# 0       22          7    2671          9             12               4
# 1       33          6    2926          9             12               2
# 2       21          4   14086         11              8               0
# 3       36          4   15336          1              6               2
# 4       11          4   19355          9             12               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   10          4   16528          7             11               2
# 32557   23          4    8080         11              8               2
# 32558   41          4    7883         11              8               6
# 32559    5          4   12881         11              8               4
# 32560   35          5   17825         11              8               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
p['Income'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# SMOTE

# %%
pip install -U imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(p.iloc[:,0:-1], p['Income'])

print('Original dataset shape', len(p))
print('Resampled dataset shape', len(y_smote))
# Out:
# Original dataset shape 32561
# Resampled dataset shape 49440

# %% [markdown]
# Spliting The Data for Testing And Training

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_smote, y_smote,test_size=0.25,random_state=42)
x_train
# Out:
#        nan  workclass  fnlwgt  education  education-num  marital-status  \
# 31995   13          5   10350         15              9               2
# 1113    52          4    9246         11              8               2
# 22385   30          4   16010          9             12               2
# 23791   31          4   13606         11              8               0
# 21374   27          1   18864         11              8               2
# ...    ...        ...     ...        ...            ...             ...
# 11284   18          4   12744          9             12               2
# 44732   34          4   11205         10              9               2
# 38158   22          4    4467         11             11               2
# 860      1          4   14130          1              6               4
# 15795   33          6    1735         11              8               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()

# %%
logreg
# Out:
# LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict=logreg.predict(x_test)

# %%
y_predict
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
acc=accuracy_score(y_test,y_predict)

# %%
acc
# Out:
# 0.7462783171521036

# %%
con=confusion_matrix(y_test,y_predict)

# %%
con
# Out:
# array([[4285, 1886],
#        [1250, 4939]], dtype=int64)

# %%
f1=f1_score(y_test,y_predict)

# %%
pre=precision_score(y_test,y_predict)

# %%
pre
# Out:
# 0.7236630036630036

# %%
recall=recall_score(y_test,y_predict)

# %%
recall
# Out:
# 0.7980287607044757
